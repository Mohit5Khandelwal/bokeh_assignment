# %% [markdown]
# Q1. How can you create a Bokeh plot using Python code?
#
# Importing these libraries
#
# import bokeh.io
# import bokeh.plotting
# bokeh.io.output_notebook()
#
# from bokeh.plotting import figure , output_file , show
# from bokeh.sampledata.iris import flowers
#
# output_file('test.html')
#
# p = figure( title = "test flower" )
# p.xaxis.axis_label = "patel length "
# p.yaxis.axis_label = "patel width"
# p.circle( flowers['petal_length'] , flowers['petal_width'] )
# show( p )

# %% [markdown]
# Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.
#
# In Bokeh, glyphs are visual markers used to represent data points in a plot. They are essentially the basic building blocks for creating visualizations. Glyphs can be used to represent different types of data, such as points, lines, bars, or patches

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

from bokeh.plotting import figure , output_file , show 
from bokeh.sampledata.iris import flowers
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fcce092b-9971-483d-856d-bb4aac77670d">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure , output_file , show 
from bokeh.sampledata.iris import flowers

output_file('test.html')

p = figure( title = "test flower" )
p.xaxis.axis_label = "patel length "
p.yaxis.axis_label = "patel width"
p.circle( flowers['petal_length'] , flowers['petal_width'] )
show( p )
# Out:
#   <div id="a1452cdb-fb4d-4580-93f4-8009324c2b30" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?

# %%
flowers.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Customize the plot 

output_file( "test2.html" )
p = figure( title = "test flower" )

# Drawing an scatter plot for sepal_length vs speal_width 
p.scatter( x = flowers[ 'sepal_width' ] , y = flowers[ 'sepal_length' ] , fill_color = "purple" , legend_label = "Data Points" , size = 10 )
show( p )
# Out:
#   <div id="ffac4f4d-08e1-4300-85bf-14e9795797f2" data-root-id="p1294" style="display: contents;"></div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in
# real time?
#
# A Bokeh server is a Python server application that allows you to create interactive plots and applications using the Bokeh library. It enables you to build web-based dashboards and data-driven applications that can be updated in real time and respond to user interactions.

# %% [markdown]
# Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?
#
# To embed a Bokeh plot into a web page or dashboard using Flask or Django, you can follow these general steps:
#
# 1. Create the Bokeh plot: Start by creating the Bokeh plot using the Bokeh library, as you would normally do. This involves defining the figure, adding glyphs, configuring plot properties, and so on.
#
# 2. Export the plot as an HTML file: Bokeh provides a method called bokeh.embed.file_html() that allows you to export the Bokeh plot as an HTML file. This function takes the plot object as an argument and returns the HTML code required to embed the plot.
#
# 3. Integrate with Flask or Django:
#
# Flask: In a Flask application, you can render the Bokeh plot by creating a route and a corresponding view function. In the view function, generate the Bokeh plot and use the file_html() method to get the HTML code. Pass this code to the template rendering engine to generate the final HTML response.
# Django: In a Django application, you can create a view function or a class-based view to generate the Bokeh plot. Similarly, use the file_html() method to obtain the HTML code. Then, pass this code to the template rendering engine to generate the final HTML response.
